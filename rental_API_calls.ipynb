# %%
import requests
import pprint

import requests

url = "https://realty-mole-property-api.p.rapidapi.com/saleListings"

querystring = {"city":"Austin","state":"TX"}

headers = {
    'x-rapidapi-host': "realty-mole-property-api.p.rapidapi.com",
    'x-rapidapi-key': "212999dd6bmsh9cacd9a36ee1ee3p1193f5jsn145bf018f3f8"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# ('[{"price":9995000,"rawAddress":"4323 Mount Bonnell Rd, Austin, Texas '
#  '78731","county":"Travis County","propertyType":"Land","addressLine1":"4323 '
#  'Mount Bonnell '
#  'Rd","city":"Austin","state":"TX","zipCode":"78731","formattedAddress":"4323 '
#  'Mount Bonnell Rd, Austin, TX '
#  '78731","lastSeen":"2022-01-05T13:26:33.683Z","listedDate":"2021-08-19T17:40:26.258Z","status":"Active","removedDate":null,"daysOnMarket":139,"createdDate":"2021-08-19T17:40:26.258Z","id":"4323-Mount-Bonnell-Rd,-Austin,-TX-78731","latitude":30.324711,"longitude":-97.773898},{"bathrooms":5,"bedrooms":5,"price":18000000,"rawAddress":"5416 '
#  'N FM 973, Austin, Texas 78724","squareFootage":6750,"county":"Travis '
#  'County","addressLine1":"5416 N FM '
#  '973","city":"Austin","state":"TX","zipCode":"78724","formattedAddress":"5416 '
#  'N FM 973, Austin, TX '
# ...

# %%
import requests

url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"

querystring = {"limit":"10"}

headers = {
    'x-rapidapi-host': "realty-mole-property-api.p.rapidapi.com",
    'x-rapidapi-key': "212999dd6bmsh9cacd9a36ee1ee3p1193f5jsn145bf018f3f8"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# ('[{"id":"52-Starling-Ct,-Roslyn,-NY-11576","addressLine1":"52 Starling '
#  'Ct","city":"Roslyn","state":"NY","zipCode":"11576","bedrooms":6,"county":"Nassau","ownerOccupied":true,"squareFootage":5689,"yearBuilt":2007,"bathrooms":7,"lotSize":15041,"propertyType":"Single '
#  'Family","taxAssessment":{"2019":{"value":2826,"land":1212,"improvements":1614}},"propertyTaxes":{"2018":{"total":35490}},"owner":{"names":["NARAYAN '
#  'AGRAWAL"],"mailingAddress":{"id":"52-Starling-Ct,-Roslyn,-NY-11576","addressLine1":"52 '
#  'Starling '
#  'Ct","city":"Roslyn","state":"NY","zipCode":"11576"}},"longitude":-73.614354,"latitude":40.803368},{"id":"1626-Grant-St,-Bellingham,-WA-98225","addressLine1":"1626 '
#  'Grant '
#  'St","city":"Bellingham","state":"WA","zipCode":"98225","bedrooms":2,"county":"Whatcom","squareFootage":1008,"yearBuilt":1973,"bathrooms":1,"lotSize":4356,"propertyType":"Single '
# ...

# %%
url = "https://realty-mole-property-api.p.rapidapi.com/zipCodes/19146"

headers = {
    'x-rapidapi-host': "realty-mole-property-api.p.rapidapi.com",
    'x-rapidapi-key': "212999dd6bmsh9cacd9a36ee1ee3p1193f5jsn145bf018f3f8"
    }

response = requests.request("GET", url, headers=headers)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# '{"id":"19146","rentalData":{"averageRent":2242.18,"minRent":495,"maxRent":8500,"totalRentals":512,"detailed":[{"bedrooms":0,"averageRent":1087.76,"minRent":495,"maxRent":1705,"totalRentals":25},{"bedrooms":1,"averageRent":1509.65,"minRent":600,"maxRent":2800,"totalRentals":141},{"bedrooms":2,"averageRent":1864.87,"minRent":900,"maxRent":8200,"totalRentals":165},{"bedrooms":3,"averageRent":2346.89,"minRent":1000,"maxRent":8500,"totalRentals":156},{"bedrooms":4,"averageRent":2711.09,"minRent":1200,"maxRent":4800,"totalRentals":23},{"bedrooms":5,"averageRent":2975,"minRent":2975,"maxRent":2975,"totalRentals":1},{"bedrooms":6,"averageRent":3200,"minRent":3200,"maxRent":3200,"totalRentals":1}],"history":{"2020-04":{"averageRent":2210.97,"minRent":685,"maxRent":8500,"totalRentals":636,"detailed":[{"bedrooms":0,"averageRent":1169.83,"minRent":825,"maxRent":1600,"totalRentals":23},{"bedrooms":1,"averageRent":1433.32,"minRent":685,"maxRent":2500,"totalRentals":147},{"bedrooms":2,"averageRent
# ...

# %%
url = "https://realty-mole-property-api.p.rapidapi.com/rentalListings"

querystring = {"state":"TX","city":"Austin"}

headers = {
    'x-rapidapi-host': "realty-mole-property-api.p.rapidapi.com",
    'x-rapidapi-key': "212999dd6bmsh9cacd9a36ee1ee3p1193f5jsn145bf018f3f8"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response.text)
# Out:
# ('[{"bathrooms":1,"bedrooms":1,"price":1405,"rawAddress":"12800 Turtle Rock Rd '
#  'Unit 24343, Austin, Texas 78729","county":"Williamson '
#  'County","propertyType":"Apartment","addressLine1":"12800 Turtle Rock '
#  'Rd","addressLine2":"Unit '
#  '24343","city":"Austin","state":"TX","zipCode":"78729","formattedAddress":"12800 '
#  'Turtle Rock Rd, Unit 24343, Austin, TX '
#  '78729","lastSeen":"2022-01-06T01:01:27.812Z","listedDate":"2021-02-12T02:44:16.651Z","status":"Active","removedDate":null,"daysOnMarket":328,"createdDate":"2020-03-11T02:52:51.835Z","id":"12800-Turtle-Rock-Rd,-Unit-24343,-Austin,-TX-78729","latitude":30.451182,"longitude":-97.774803},{"bathrooms":1,"bedrooms":1,"price":1376,"rawAddress":"10015 '
#  'Lake Creek Pkwy Unit 16351, Austin, Texas 78729","county":"Williamson '
#  'County","propertyType":"Apartment","addressLine1":"10015 Lake Creek '
#  'Pkwy","addressLine2":"Unit '
# ...
